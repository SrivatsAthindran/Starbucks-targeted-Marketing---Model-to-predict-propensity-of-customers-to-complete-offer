# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np
import pandas as pd
from sklearn import model_selection
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from itertools import cycle
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras import regularizers
import seaborn as sns
# Out:
# In C:\Users\PKN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\PKN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\PKN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\PKN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\PKN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\PKN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\PKN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\PKN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %% [markdown]
# ### Load all json files

# %%
portfolio = pd.read_json('F:/Customer Analytics and Applications/Project/data/portfolio.json', lines = True)
profile = pd.read_json('F:/Customer Analytics and Applications/Project/data/profile.json', lines = True)
transcript = pd.read_json('F:/Customer Analytics and Applications/Project/data/transcript.json', lines = True)

# %%
pd.set_option('display.max_columns',50)

# %% [markdown]
# ### Portfolio data preparation

# %%
portfolio.head(10)
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10         7           bogo
# 1      10  [web, email, mobile, social]          10         5           bogo
# 2       0          [web, email, mobile]           0         4  informational
# 3       5          [web, email, mobile]           5         7           bogo
# 4       5                  [web, email]          20        10       discount
# 5       3  [web, email, mobile, social]           7         7       discount
# 6       2  [web, email, mobile, social]          10        10       discount
# 7       0       [email, mobile, social]           0         3  informational
# 8       5  [web, email, mobile, social]           5         5           bogo
# 9       2          [web, email, mobile]          10         7       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# 2  3f207df678b143eea3cee63160fa8bed
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 6  fafdcd668e3743c1bb461111dcafc2a4
# 7  5a8bc65990b245e5a138643cd4eb9837
# 8  f19421c1d4aa40978ebb69ca19b0e20d
# 9  2906b810c7d4411798c6938adc9daaa5

# %%
portfolio = portfolio.explode('channels')

# %%
portfolio = pd.concat([portfolio, pd.get_dummies(portfolio['channels'], prefix = 'Is Offer on', prefix_sep = ' ')], axis = 1).drop('channels', axis = 1)

# %%
portfolio = portfolio.groupby(['id','reward','difficulty','duration','offer_type'], as_index = False).agg({'Is Offer on email': np.sum,
                                                         'Is Offer on mobile': np.sum,
                                                         'Is Offer on social': np.sum,
                                                         'Is Offer on web': np.sum})

# %%
portfolio = portfolio.rename(columns={"id": "offer_id"})

# %%
portfolio
# Out:
#                            offer_id  reward  difficulty  duration  \
# 0  0b1e1539f2cc45b7b9fa7c272da2e1d7       5          20        10
# 1  2298d6c36e964ae4a3e7e9706d1fb8c2       3           7         7
# 2  2906b810c7d4411798c6938adc9daaa5       2          10         7
# 3  3f207df678b143eea3cee63160fa8bed       0           0         4
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0      10          10         5
# 5  5a8bc65990b245e5a138643cd4eb9837       0           0         3
# 6  9b98b8c7a33c4b65b9aebfe6a799e6d9       5           5         7
# 7  ae264e3637204a6fb9bb56bc8210ddfd      10          10         7
# 8  f19421c1d4aa40978ebb69ca19b0e20d       5           5         5
# 9  fafdcd668e3743c1bb461111dcafc2a4       2          10        10
#
#       offer_type  Is Offer on email  Is Offer on mobile  Is Offer on social  \
# 0       discount                  1                   0                   0
# 1       discount                  1                   1                   1
# 2       discount                  1                   1                   0
# 3  informational                  1                   1                   0
# 4           bogo                  1                   1                   1
# 5  informational                  1                   1                   1
# 6           bogo                  1                   1                   0
# 7           bogo                  1                   1                   1
# 8           bogo                  1                   1                   1
# 9       discount                  1                   1                   1
#
#    Is Offer on web
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# 5                0
# 6                1
# 7                0
# 8                1
# 9                1

# %% [markdown]
# ### Profile data preparation

# %%
profile.head(10)
# Out:
#   gender  age                                id  became_member_on    income
# 0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 2   None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712       NaN
# 3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 4   None  118  a03223e636434f42ac4c3df47e8bac43          20170804       NaN
# 5      M   68  e2127556f4f64592b11af22de27a7932          20180426   70000.0
# 6   None  118  8ec6ce2a7e7949b1bf142def7d0e0586          20170925       NaN
# 7   None  118  68617ca6246f4fbc85e91a2a49552598          20171002       NaN
# 8      M   65  389bc3fa690240e798340f5a15918d5c          20180209   53000.0
# 9   None  118  8974fc5686fe429db53ddde067b88302          20161122       NaN

# %%
profile.shape
# Out:
# (17000, 5)

# %%
profile = profile[~(profile['age']==118)]

# %%
profile.shape
# Out:
# (14825, 5)

# %%
profile['gender'].value_counts()
# Out:
# M    8484
# F    6129
# O     212
# Name: gender, dtype: int64

# %%
profile['income'].describe()
# Out:
# count     14825.000000
# mean      65404.991568
# std       21598.299410
# min       30000.000000
# 25%       49000.000000
# 50%       64000.000000
# 75%       80000.000000
# max      120000.000000
# Name: income, dtype: float64

# %%
profile = profile.rename(columns={"id": "person"})

# %%
profile.head(10)
# Out:
#    gender  age                            person  became_member_on    income
# 1       F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0
# 3       F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509  100000.0
# 5       M   68  e2127556f4f64592b11af22de27a7932          20180426   70000.0
# 8       M   65  389bc3fa690240e798340f5a15918d5c          20180209   53000.0
# 12      M   58  2eeac8d8feae4a8cad5a6af0499a211d          20171111   51000.0
# 13      F   61  aa4862eba776480b8bb9c68455b8c2e1          20170911   57000.0
# 14      M   26  e12aeaf2d47d42479ea1c4ac3d8286c6          20140213   46000.0
# 15      F   62  31dda685af34476cad5bc968bdb01c53          20160211   71000.0
# 16      M   49  62cf5e10845442329191fc246e7bcea3          20141113   52000.0
# 18      M   57  6445de3b47274c759400cd68131d91b4          20171231   42000.0

# %% [markdown]
# ### Transcript data preparation

# %%
transcript.head(10)
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
# 2  e2127556f4f64592b11af22de27a7932  offer received
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4  68617ca6246f4fbc85e91a2a49552598  offer received
# 5  389bc3fa690240e798340f5a15918d5c  offer received
# 6  c4863c7985cf408faee930f111475da3  offer received
# 7  2eeac8d8feae4a8cad5a6af0499a211d  offer received
# 8  aa4862eba776480b8bb9c68455b8c2e1  offer received
# 9  31dda685af34476cad5bc968bdb01c53  offer received
#
#                                               value  time
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0
# 5  {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}     0
# 6  {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}     0
# 7  {'offer id': '3f207df678b143eea3cee63160fa8bed'}     0
# 8  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 9  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0

# %%
transcript[transcript['person']=='78afa995795e4d85b5d9ceeca43f5fef']
# Out:
#                                   person            event  \
# 0       78afa995795e4d85b5d9ceeca43f5fef   offer received
# 15561   78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 47582   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 47583   78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 49502   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 53176   78afa995795e4d85b5d9ceeca43f5fef   offer received
# 85291   78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 87134   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 92104   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 141566  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 150598  78afa995795e4d85b5d9ceeca43f5fef   offer received
# 163375  78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 201572  78afa995795e4d85b5d9ceeca43f5fef   offer received
# 218393  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 218394  78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 218395  78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 230412  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 262138  78afa995795e4d85b5d9ceeca43f5fef     offer viewed
#
#                                                     value  time
# 0        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 15561    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     6
# 47582                                   {'amount': 19.89}   132
# 47583   {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   132
# 49502                                   {'amount': 17.78}   144
# 53176    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   168
# 85291    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   216
# 87134                                   {'amount': 19.67}   222
# 92104                                   {'amount': 29.72}   240
# 141566                                  {'amount': 23.93}   378
# 150598   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}   408
# 163375   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}   408
# 201572   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   504
# 218393                                  {'amount': 21.72}   510
# 218394  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...   510
# 218395  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...   510
# 230412                                  {'amount': 26.56}   534
# 262138   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   582

# %%
## Remove offer id and amount from dictionary data type inside value column - Transfer the values to new column

# %%
values=[]
for i in transcript['value']:
    values.append(list(i.values())[0])

# %%
transcript['value_new'] = pd.Series()

# %%
transcript['value_new'] = values

# %%
transcript[transcript['person']=='78afa995795e4d85b5d9ceeca43f5fef']
# Out:
#                                   person            event  \
# 0       78afa995795e4d85b5d9ceeca43f5fef   offer received
# 15561   78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 47582   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 47583   78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 49502   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 53176   78afa995795e4d85b5d9ceeca43f5fef   offer received
# 85291   78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 87134   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 92104   78afa995795e4d85b5d9ceeca43f5fef      transaction
# 141566  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 150598  78afa995795e4d85b5d9ceeca43f5fef   offer received
# 163375  78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 201572  78afa995795e4d85b5d9ceeca43f5fef   offer received
# 218393  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 218394  78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 218395  78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 230412  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 262138  78afa995795e4d85b5d9ceeca43f5fef     offer viewed
#
#                                                     value  time  \
# 0        {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 15561    {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     6
# 47582                                   {'amount': 19.89}   132
# 47583   {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   132
# 49502                                   {'amount': 17.78}   144
# 53176    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   168
# 85291    {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   216
# 87134                                   {'amount': 19.67}   222
# 92104                                   {'amount': 29.72}   240
# 141566                                  {'amount': 23.93}   378
# 150598   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}   408
# 163375   {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}   408
# 201572   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   504
# 218393                                  {'amount': 21.72}   510
# 218394  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...   510
# 218395  {'offer_id': 'f19421c1d4aa40978ebb69ca19b0e20d...   510
# 230412                                  {'amount': 26.56}   534
# 262138   {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}   582
#
#                                value_new
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9
# 15561   9b98b8c7a33c4b65b9aebfe6a799e6d9
# 47582                              19.89
# 47583   9b98b8c7a33c4b65b9aebfe6a799e6d9
# 49502                              17.78
# 53176   5a8bc65990b245e5a138643cd4eb9837
# 85291   5a8bc65990b245e5a138643cd4eb9837
# 87134                              19.67
# 92104                              29.72
# 141566                             23.93
# 150598  ae264e3637204a6fb9bb56bc8210ddfd
# 163375  ae264e3637204a6fb9bb56bc8210ddfd
# 201572  f19421c1d4aa40978ebb69ca19b0e20d
# 218393                             21.72
# 218394  ae264e3637204a6fb9bb56bc8210ddfd
# 218395  f19421c1d4aa40978ebb69ca19b0e20d
# 230412                             26.56
# 262138  f19421c1d4aa40978ebb69ca19b0e20d

# %%
transcript = transcript.sort_values(['person','time'], ascending = True)

# %%
offers = []
for i in transcript['value_new']:
    if type(i)==str:
        offers.append(i)
    else:
        j = offers[-1]
        offers.append(j) 
transcript['offer_id'] = offers

# %%
amounts = []
for i in transcript['value_new']:
    if type(i)==str:
        amounts.append(0)
    else:
        amounts.append(i) 
transcript['transaction_amount'] = amounts

# %%
del transcript['value'], transcript['value_new']

# %%
transcript[transcript['person']=='78afa995795e4d85b5d9ceeca43f5fef']
# Out:
#                                   person            event  time  \
# 0       78afa995795e4d85b5d9ceeca43f5fef   offer received     0
# 15561   78afa995795e4d85b5d9ceeca43f5fef     offer viewed     6
# 47582   78afa995795e4d85b5d9ceeca43f5fef      transaction   132
# 47583   78afa995795e4d85b5d9ceeca43f5fef  offer completed   132
# 49502   78afa995795e4d85b5d9ceeca43f5fef      transaction   144
# 53176   78afa995795e4d85b5d9ceeca43f5fef   offer received   168
# 85291   78afa995795e4d85b5d9ceeca43f5fef     offer viewed   216
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 15561   9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 47582   9b98b8c7a33c4b65b9aebfe6a799e6d9               19.89
# 47583   9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 49502   9b98b8c7a33c4b65b9aebfe6a799e6d9               17.78
# 53176   5a8bc65990b245e5a138643cd4eb9837                0.00
# 85291   5a8bc65990b245e5a138643cd4eb9837                0.00
# 87134   5a8bc65990b245e5a138643cd4eb9837               19.67
# 92104   5a8bc65990b245e5a138643cd4eb9837               29.72
# 141566  5a8bc65990b245e5a138643cd4eb9837               23.93
# 150598  ae264e3637204a6fb9bb56bc8210ddfd                0.00
# 163375  ae264e3637204a6fb9bb56bc8210ddfd                0.00
# 201572  f19421c1d4aa40978ebb69ca19b0e20d                0.00
# 218393  f19421c1d4aa40978ebb69ca19b0e20d               21.72
# 218394  ae264e3637204a6fb9bb56bc8210ddfd                0.00
# 218395  f19421c1d4aa40978ebb69ca19b0e20d                0.00
# 230412  f19421c1d4aa40978ebb69ca19b0e20d               26.56
# 262138  f19421c1d4aa40978ebb69ca19b0e20d                0.00
#
#         event_=_offer completed  event_=_offer received  event_=_offer viewed  \
# 0                             0                       1                     0
# 15561                         0                       0                     1
# 47582                         0                       0                     0
# 47583                         1                       0                     0
# 49502                         0                       0                     0
# 53176                         0                       1                     0
# 85291                         0                       0                     1
# 87134                         0                       0                     0
# 92104                         0                       0                     0
# 141566                        0                       0                     0
# 150598                        0                       1                     0
# 163375                        0                       0                     1
# 201572                        0                       1                     0
# 218393                        0                       0                     0
# 218394                        1                       0                     0
# 218395                        1                       0                     0
# 230412                        0                       0                     0
# 262138                        0                       0                     1
#
#         event_=_transaction
# 0                         0
# 15561                     0
# 47582                     1
# 47583                     0
# 49502                     1
# 53176                     0
# 85291                     0
# 87134                     1
# 92104                     1
# 141566                    1
# 150598                    0
# 163375                    0
# 201572                    0
# 218393                    1
# 218394                    0
# 218395                    0
# 230412                    1
# 262138                    0

# %%
transcript_new.columns
# Out:
# Index(['person', 'time', 'offer_id', 'transaction_amount',
#        'event_=_offer completed', 'event_=_offer received',
#        'event_=_offer viewed', 'event_=_transaction'],
#       dtype='object')

# %%
transcript_new2 = transcript_new.groupby(['person','offer_id'], as_index = False).agg({'event_=_offer completed': np.sum,
                                                            'event_=_offer received':np.sum,
                                                            'event_=_offer viewed':np.sum})

# %%
transcript_new3 = transcript_new.groupby('person', as_index = False).agg({'transaction_amount': np.sum,
                                                            'event_=_transaction':np.sum})

# %%
transcript_new2 = pd.DataFrame(transcript_new2)
transcript_new3 = pd.DataFrame(transcript_new3)

# %%
transcript_new2.head()
# Out:
#                              person                          offer_id  \
# 0  0009655768c64bdeb2e877511632db8f  2906b810c7d4411798c6938adc9daaa5
# 1  0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 2  0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 3  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 4  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
#
#    event_=_offer completed  event_=_offer received  event_=_offer viewed
# 0                        1                       1                     0
# 1                        0                       1                     1
# 2                        0                       1                     1
# 3                        1                       1                     1
# 4                        1                       1                     1

# %%
transcript_new2 = transcript_new2.merge(portfolio, on = 'offer_id', how = 'left')

# %%
transcript_new2 = pd.concat([transcript_new2,pd.get_dummies(transcript_new2['offer_type'], prefix = 'No. of offers given',  prefix_sep = '_=_')], axis = 1).drop('offer_type', axis = 1)

# %%
transcript_new2 = transcript_new2.groupby('person', as_index = False).agg({'event_=_offer completed': np.sum,
                                                                          'event_=_offer received': np.sum,
                                                                          'event_=_offer viewed': np.sum,
                                                                          'reward': np.mean,
                                                                          'difficulty':np.mean,
                                                                          'duration':np.mean,
                                                                          'Is Offer on mobile': np.sum,
                                                                          'Is Offer on social': np.sum,
                                                                          'Is Offer on web': np.sum,
                                                                          'Is Offer on email': np.sum,
                                                                          'No. of offers given_=_bogo':np.sum,
                                                                          'No. of offers given_=_discount': np.sum,
                                                                          'No. of offers given_=_informational':np.sum})

# %%
transcript_new2 = transcript_new2.rename(columns = {'Is Offer on mobile':'No of offers given avail on mobile',
                                                   'Is Offer on web':'No of offers given avail on web',
                                                   'Is Offer on social':'No of offers given avail on social',
                                                   'Is Offer on email':'No of offers given avail on email',
                                                   'event_=_offer viewed':'No of offers viewed',
                                                   'difficulty':'Avg offer min spend',
                                                   'duration':'Avg offer duration',
                                                   'reward':'Avg reward pts for offers given'})

# %%
transcript_new2.head()
# Out:
#                              person  event_=_offer completed  \
# 0  0009655768c64bdeb2e877511632db8f                        3
# 1  00116118485d4dfda04fdbaba9a87b5c                        0
# 2  0011e0d4e6b944f998e987f904e8c1e5                        3
# 3  0020c2b971eb4e9188eac86d93036a77                        3
# 4  0020ccbbb6d84e358d3414a3ff76cffd                        3
#
#    event_=_offer received  No of offers viewed  \
# 0                       5                    4
# 1                       2                    2
# 2                       5                    5
# 3                       5                    3
# 4                       4                    4
#
#    Avg reward pts for offers given  Avg offer min spend  Avg offer duration  \
# 0                             1.80                 5.00                5.80
# 1                             5.00                 5.00                5.00
# 2                             2.60                 6.40                6.20
# 3                             5.50                 7.50                6.25
# 4                             3.25                 4.25                5.50
#
#    No of offers given avail on mobile  No of offers given avail on social  \
# 0                                   5                                   3
# 1                                   1                                   1
# 2                                   4                                   2
# 3                                   4                                   4
# 4                                   4                                   3
#
#    No of offers given avail on web  No of offers given avail on email  \
# 0                                4                                  5
# 1                                1                                  1
# 2                                4                                  5
# 3                                2                                  4
# 4                                3                                  4
#
#    No. of offers given_=_bogo  No. of offers given_=_discount  \
# 0                           1                               2
# 1                           1                               0
# 2                           1                               2
# 3                           2                               1
# 4                           2                               1
#
#    No. of offers given_=_informational
# 0                                    2
# 1                                    0
# 2                                    2
# 3                                    1
# 4                                    1

# %%
transcript_new3 = transcript_new3.rename(columns = {'transaction_amount':'Total spend',
                                                   'event_=_transaction':'No of transactions'})

# %%
transcript_new3.head()
# Out:
#                              person  Total spend  No of transactions
# 0  0009655768c64bdeb2e877511632db8f       127.60                   8
# 1  00116118485d4dfda04fdbaba9a87b5c         4.09                   3
# 2  0011e0d4e6b944f998e987f904e8c1e5        79.46                   5
# 3  0020c2b971eb4e9188eac86d93036a77       196.86                   8
# 4  0020ccbbb6d84e358d3414a3ff76cffd       154.05                  12

# %%
transcript_new4 = transcript_new2.merge(transcript_new3, on = 'person', how = 'left')

# %%
transcript_new4 = pd.DataFrame(transcript_new4)
transcript_new4.head()
# Out:
#                              person  event_=_offer completed  \
# 0  0009655768c64bdeb2e877511632db8f                        3
# 1  00116118485d4dfda04fdbaba9a87b5c                        0
# 2  0011e0d4e6b944f998e987f904e8c1e5                        3
# 3  0020c2b971eb4e9188eac86d93036a77                        3
# 4  0020ccbbb6d84e358d3414a3ff76cffd                        3
#
#    event_=_offer received  No of offers viewed  \
# 0                       5                    4
# 1                       2                    2
# 2                       5                    5
# 3                       5                    3
# 4                       4                    4
#
#    Avg reward pts for offers given  Avg offer min spend  Avg offer duration  \
# 0                             1.80                 5.00                5.80
# 1                             5.00                 5.00                5.00
# 2                             2.60                 6.40                6.20
# 3                             5.50                 7.50                6.25
# 4                             3.25                 4.25                5.50
#
#    No of offers given avail on mobile  No of offers given avail on social  \
# 0                                   5                                   3
# 1                                   1                                   1
# 2                                   4                                   2
# 3                                   4                                   4
# 4                                   4                                   3
#
#    No of offers given avail on web  No of offers given avail on email  \
# 0                                4                                  5
# 1                                1                                  1
# 2                                4                                  5
# 3                                2                                  4
# 4                                3                                  4
#
#    No. of offers given_=_bogo  No. of offers given_=_discount  \
# 0                           1                               2
# 1                           1                               0
# 2                           1                               2
# 3                           2                               1
# 4                           2                               1
#
#    No. of offers given_=_informational  Total spend  No of transactions
# 0                                    2       127.60                   8
# 1                                    0         4.09                   3
# 2                                    2        79.46                   5
# 3                                    1       196.86                   8
# 4                                    1       154.05                  12

# %%
transcript_new4[transcript_new4['person']=='78afa995795e4d85b5d9ceeca43f5fef']
# Out:
#                                 person  event_=_offer completed  \
# 7996  78afa995795e4d85b5d9ceeca43f5fef                        3
#
#       event_=_offer received  No of offers viewed  \
# 7996                       4                    4
#
#       Avg reward pts for offers given  Avg offer min spend  \
# 7996                              5.0                  5.0
#
#       Avg offer duration  No of offers given avail on mobile  \
# 7996                 5.5                                   4
#
#       No of offers given avail on social  No of offers given avail on web  \
# 7996                                   3                                2
#
#       No of offers given avail on email  No. of offers given_=_bogo  \
# 7996                                  4                           3
#
#       No. of offers given_=_discount  No. of offers given_=_informational  \
# 7996                               0                                    1
#
#       Total spend  No of transactions
# 7996       159.27                   7

# %%
transcript_new4.shape
# Out:
# (17000, 16)

# %%
transcript_new4['event_=_offer completed'].value_counts()
# Out:
# 0    4226
# 2    3202
# 1    3140
# 3    3062
# 4    2201
# 5     969
# 6     200
# Name: event_=_offer completed, dtype: int64

# %%
transcript[(transcript['person']=='073fce5708884b30a28b65b3cb15a919')&(transcript['offer_id']=='9b98b8c7a33c4b65b9aebfe6a799e6d9')]
# Out:
#                                   person            event  time  \
# 2268    073fce5708884b30a28b65b3cb15a919   offer received     0
# 13189   073fce5708884b30a28b65b3cb15a919     offer viewed     0
# 38456   073fce5708884b30a28b65b3cb15a919      transaction    84
# 38457   073fce5708884b30a28b65b3cb15a919  offer completed    84
# 45653   073fce5708884b30a28b65b3cb15a919      transaction   120
# 50604   073fce5708884b30a28b65b3cb15a919      transaction   150
# 55466   073fce5708884b30a28b65b3cb15a919   offer received   168
# 66500   073fce5708884b30a28b65b3cb15a919     offer viewed   168
# 87449   073fce5708884b30a28b65b3cb15a919      transaction   222
# 87450   073fce5708884b30a28b65b3cb15a919  offer completed   222
# 101665  073fce5708884b30a28b65b3cb15a919      transaction   282
# 152880  073fce5708884b30a28b65b3cb15a919   offer received   408
# 168263  073fce5708884b30a28b65b3cb15a919      transaction   414
# 168264  073fce5708884b30a28b65b3cb15a919  offer completed   414
# 171734  073fce5708884b30a28b65b3cb15a919     offer viewed   420
# 191590  073fce5708884b30a28b65b3cb15a919      transaction   468
# 203837  073fce5708884b30a28b65b3cb15a919   offer received   504
# 215029  073fce5708884b30a28b65b3cb15a919     offer viewed   504
# 215030  073fce5708884b30a28b65b3cb15a919      transaction   504
# 215031  073fce5708884b30a28b65b3cb15a919  offer completed   504
# 222476  073fce5708884b30a28b65b3cb15a919      transaction   516
# 235584  073fce5708884b30a28b65b3cb15a919      transaction   546
#
#                                 offer_id  transaction_amount
# 2268    9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 13189   9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 38456   9b98b8c7a33c4b65b9aebfe6a799e6d9               25.35
# 38457   9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 45653   9b98b8c7a33c4b65b9aebfe6a799e6d9               18.86
# 50604   9b98b8c7a33c4b65b9aebfe6a799e6d9               15.07
# 55466   9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 66500   9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 87449   9b98b8c7a33c4b65b9aebfe6a799e6d9               15.21
# 87450   9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 101665  9b98b8c7a33c4b65b9aebfe6a799e6d9               32.08
# 152880  9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 168263  9b98b8c7a33c4b65b9aebfe6a799e6d9               20.74
# 168264  9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 171734  9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 191590  9b98b8c7a33c4b65b9aebfe6a799e6d9               27.05
# 203837  9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 215029  9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 215030  9b98b8c7a33c4b65b9aebfe6a799e6d9               29.50
# 215031  9b98b8c7a33c4b65b9aebfe6a799e6d9                0.00
# 222476  9b98b8c7a33c4b65b9aebfe6a799e6d9               26.91
# 235584  9b98b8c7a33c4b65b9aebfe6a799e6d9               40.27

# %% [markdown]
# ### Derive usage rate
# #### Usage rate = (no of offers completed/no of offers received)*100

# %%
transcript_new4['usage_rate'] = (transcript_new4['event_=_offer completed']/transcript_new4['event_=_offer received'])*100

# %%
transcript_new4[transcript_new4['event_=_offer completed']==4]
# Out:
#                                  person  event_=_offer completed  \
# 18     0091d2b6a5ea4defaa8393e4e816db60                        4
# 24     00ae03011f9f49b8a4b3e6d416678b0b                        4
# 34     00c20a9202d5475190b31a24de6fb06d                        4
# 44     00d791e20c564add8056498e40eb56cc                        4
# 54     00fac72fd6ad448e8019b175267023df                        4
# ...                                 ...                      ...
# 16972  ff992fbec53145bbae59a68d025e0458                        4
# 16974  ff9f73ead16a4f9b9e1a53a27280af92                        4
# 16975  ffa81afacde642a3a51a7cd99f8d2cd7                        4
# 16977  ffaecba5bbb14cffb04c2490d18eee7e                        4
# 16979  ffb7fc8ad0594248a49e210ff0217c2d                        4
#
#        event_=_offer received  No of offers viewed  \
# 18                          5                    5
# 24                          6                    5
# 34                          4                    4
# 44                          5                    5
# 54                          4                    4
# ...                       ...                  ...
# 16972                       6                    6
# 16974                       4                    3
# 16975                       5                    2
# 16977                       6                    5
# 16979                       6                    4
#
#        Avg reward pts for offers given  Avg offer min spend  \
# 18                            6.666667            11.666667
# 24                            3.750000             6.750000
# 34                            5.750000            10.500000
# 44                            4.600000             5.400000
# 54                            7.500000            15.000000
# ...                                ...                  ...
# 16972                         5.000000             7.400000
# 16974                         5.500000            11.250000
# 16975                         3.333333             8.333333
# 16977                         5.333333             9.166667
# 16979                         2.400000             7.000000
#
#        Avg offer duration  No of offers given avail on mobile  \
# 18               6.666667                                   2
# 24               6.000000                                   4
# 34               6.750000                                   3
# 44               5.400000                                   5
# 54               8.500000                                   1
# ...                   ...                                 ...
# 16972            7.200000                                   5
# 16974            7.500000                                   3
# 16975            6.333333                                   2
# 16977            7.166667                                   5
# 16979            6.400000                                   4
#
#        No of offers given avail on social  No of offers given avail on web  \
# 18                                      2                                3
# 24                                      3                                2
# 34                                      3                                4
# 44                                      4                                4
# 54                                      1                                1
# ...                                   ...                              ...
# 16972                                   4                                4
# 16974                                   3                                4
# 16975                                   1                                3
# 16977                                   3                                5
# 16979                                   3                                4
#
#        No of offers given avail on email  No. of offers given_=_bogo  \
# 18                                     3                           2
# 24                                     4                           1
# 34                                     4                           2
# 44                                     5                           3
# 54                                     2                           1
# ...                                  ...                         ...
# 16972                                  5                           3
# 16974                                  4                           2
# 16975                                  3                           1
# 16977                                  6                           3
# 16979                                  5                           1
#
#        No. of offers given_=_discount  No. of offers given_=_informational  \
# 18                                  1                                    0
# 24                                  2                                    1
# 34                                  2                                    0
# 44                                  1                                    1
# 54                                  1                                    0
# ...                               ...                                  ...
# 16972                               2                                    0
# 16974                               2                                    0
# 16975                               1                                    1
# 16977                               2                                    1
# 16979                               2                                    2
#
#        Total spend  No of transactions  usage_rate
# 18          279.16                  12   80.000000
# 24          218.05                   8   66.666667
# 34          164.01                   8  100.000000
# 44           59.62                  19   80.000000
# 54          186.23                  10  100.000000
# ...            ...                 ...         ...
# 16972        73.91                  24   66.666667
# 16974       263.30                  15  100.000000
# 16975       275.36                  10   80.000000
# 16977       174.33                   7   66.666667
# 16979       166.52                   7   66.666667
#
# [2201 rows x 17 columns]

# %%
transcript_new4.describe()
# Out:
#        event_=_offer completed  event_=_offer received  No of offers viewed  \
# count             17000.000000            17000.000000         17000.000000
# mean                  1.975235                4.486882             3.395588
# std                   1.605563                1.076165             1.297653
# min                   0.000000                0.000000             0.000000
# 25%                   1.000000                4.000000             2.750000
# 50%                   2.000000                5.000000             3.000000
# 75%                   3.000000                5.000000             4.000000
# max                   6.000000                6.000000             6.000000
#
#        Avg reward pts for offers given  Avg offer min spend  \
# count                     17000.000000         17000.000000
# mean                          4.207543             7.718017
# std                           1.527846             2.504153
# min                           0.000000             0.000000
# 25%                           3.000000             6.000000
# 50%                           4.250000             7.500000
# 75%                           5.000000             9.250000
# max                          10.000000            20.000000
#
#        Avg offer duration  No of offers given avail on mobile  \
# count        17000.000000                        17000.000000
# mean             6.507025                            3.439824
# std              0.992975                            0.997746
# min              3.000000                            0.000000
# 25%              5.800000                            3.000000
# 50%              6.500000                            3.000000
# 75%              7.200000                            4.000000
# max             10.000000                            6.000000
#
#        No of offers given avail on social  No of offers given avail on web  \
# count                        17000.000000                     17000.000000
# mean                             2.294353                         3.059235
# std                              0.969232                         1.000775
# min                              0.000000                         0.000000
# 25%                              2.000000                         2.000000
# 50%                              2.000000                         3.000000
# 75%                              3.000000                         4.000000
# max                              6.000000                         6.000000
#
#        No of offers given avail on email  No. of offers given_=_bogo  \
# count                       17000.000000                17000.000000
# mean                            3.824765                    1.528941
# std                             0.965825                    0.865295
# min                             1.000000                    0.000000
# 25%                             3.000000                    1.000000
# 50%                             4.000000                    2.000000
# 75%                             4.000000                    2.000000
# max                             6.000000                    4.000000
#
#        No. of offers given_=_discount  No. of offers given_=_informational  \
# count                    17000.000000                         17000.000000
# mean                         1.532412                             0.763412
# std                          0.871878                             0.663541
# min                          0.000000                             0.000000
# 25%                          1.000000                             0.000000
# 50%                          2.000000                             1.000000
# 75%                          2.000000                             1.000000
# max                          4.000000                             2.000000
#
#         Total spend  No of transactions    usage_rate
# count  17000.000000        17000.000000  16994.000000
# mean     104.438351            8.173706     43.995234
# std      125.922619            5.116250     33.939511
# min        0.000000            0.000000      0.000000
# 25%       21.820000            4.000000     16.666667
# 50%       69.405000            7.000000     50.000000
# 75%      148.782500           11.000000     75.000000
# max     1608.690000           36.000000    100.000000

# %%
transcript_new4 = transcript_new4[~transcript_new4['usage_rate'].isna()==True]

# %%
transcript_new4.shape
# Out:
# (16994, 17)

# %%
transcript_new4['usage_rate'].value_counts()
# Out:
# 0.000000      4220
# 100.000000    1916
# 50.000000     1736
# 66.666667     1113
# 80.000000     1109
# 75.000000     1100
# 60.000000     1094
# 33.333333     1016
# 40.000000      975
# 25.000000      947
# 20.000000      916
# 83.333333      437
# 16.666667      415
# Name: usage_rate, dtype: int64

# %% [markdown]
# ### Merge all datasets into one and create target variable - Usage class:
# #### 0%usage rate - Class 0 - No use category(will not use the offer at all)
# #### Between 0-100%usage rate - Class 1 - Fickle minded category(will use the offer sometimes)
# #### 100%usage rate - Class 2 - Sureshot users category(will use the given offer everytime)

# %%
df = transcript_new4.merge(profile, on = 'person',how = 'inner')

# %%
df.head(10)
# Out:
#                              person  event_=_offer completed  \
# 0  0009655768c64bdeb2e877511632db8f                        3
# 1  0011e0d4e6b944f998e987f904e8c1e5                        3
# 2  0020c2b971eb4e9188eac86d93036a77                        3
# 3  0020ccbbb6d84e358d3414a3ff76cffd                        3
# 4  003d66b6608740288d6cc97a6903f4f0                        3
# 5  00426fe3ffde4c6b9cb9ad6d077a13ea                        1
# 6  004b041fbfe44859945daa2c7f79ee64                        2
# 7  004c5799adbf42868b9cff0396190900                        5
# 8  005500a7188546ff8a767329a2f7c76a                        1
# 9  0056df74b63b4298809f0b375a304cf4                        3
#
#    event_=_offer received  No of offers viewed  \
# 0                       5                    4
# 1                       5                    5
# 2                       5                    3
# 3                       4                    4
# 4                       5                    4
# 5                       5                    2
# 6                       3                    2
# 7                       5                    4
# 8                       5                    3
# 9                       4                    3
#
#    Avg reward pts for offers given  Avg offer min spend  Avg offer duration  \
# 0                         1.800000             5.000000            5.800000
# 1                         2.600000             6.400000            6.200000
# 2                         5.500000             7.500000            6.250000
# 3                         3.250000             4.250000            5.500000
# 4                         1.750000             7.500000            6.750000
# 5                         2.250000            10.000000            7.500000
# 6                         2.250000             6.250000            6.500000
# 7                         5.666667             8.333333            7.333333
# 8                         5.666667             8.333333            7.000000
# 9                         3.250000             8.000000            7.000000
#
#    No of offers given avail on mobile  No of offers given avail on social  \
# 0                                   5                                   3
# 1                                   4                                   2
# 2                                   4                                   4
# 3                                   4                                   3
# 4                                   3                                   2
# 5                                   3                                   2
# 6                                   4                                   2
# 7                                   3                                   3
# 8                                   3                                   1
# 9                                   3                                   1
#
#    No of offers given avail on web  No of offers given avail on email  \
# 0                                4                                  5
# 1                                4                                  5
# 2                                2                                  4
# 3                                3                                  4
# 4                                3                                  4
# 5                                3                                  4
# 6                                4                                  4
# 7                                2                                  3
# 8                                2                                  3
# 9                                4                                  4
#
#    No. of offers given_=_bogo  No. of offers given_=_discount  \
# 0                           1                               2
# 1                           1                               2
# 2                           2                               1
# 3                           2                               1
# 4                           0                               2
# 5                           0                               3
# 6                           1                               2
# 7                           2                               1
# 8                           2                               1
# 9                           1                               2
#
#    No. of offers given_=_informational  Total spend  No of transactions  \
# 0                                    2       127.60                   8
# 1                                    2        79.46                   5
# 2                                    1       196.86                   8
# 3                                    1       154.05                  12
# 4                                    2        48.34                  18
# 5                                    1        68.51                  17
# 6                                    1       138.36                   6
# 7                                    0       347.38                  12
# 8                                    0        20.36                   4
# 9                                    1       144.14                   5
#
#    usage_rate gender  age  became_member_on   income
# 0   60.000000      M   33          20170421  72000.0
# 1   60.000000      O   40          20180109  57000.0
# 2   60.000000      F   59          20160304  90000.0
# 3   75.000000      F   24          20161111  60000.0
# 4   60.000000      F   26          20170621  73000.0
# 5   20.000000      F   19          20160809  65000.0
# 6   66.666667      F   55          20180508  74000.0
# 7  100.000000      M   54          20160331  99000.0
# 8   20.000000      M   56          20171209  47000.0
# 9   75.000000      M   54          20160821  91000.0

# %%
df['usage_class'] = pd.Series()

# %%
usage_class = []
for i in df['usage_rate']:
    if i ==0.0:
        usage_class.append('0')
    elif i==100:
        usage_class.append('2')
    else:
        usage_class.append('1')

# %%
df['usage_class'] = usage_class

# %%
df.head(10)
# Out:
#                              person  event_=_offer completed  \
# 0  0009655768c64bdeb2e877511632db8f                        3
# 1  0011e0d4e6b944f998e987f904e8c1e5                        3
# 2  0020c2b971eb4e9188eac86d93036a77                        3
# 3  0020ccbbb6d84e358d3414a3ff76cffd                        3
# 4  003d66b6608740288d6cc97a6903f4f0                        3
# 5  00426fe3ffde4c6b9cb9ad6d077a13ea                        1
# 6  004b041fbfe44859945daa2c7f79ee64                        2
# 7  004c5799adbf42868b9cff0396190900                        5
# 8  005500a7188546ff8a767329a2f7c76a                        1
# 9  0056df74b63b4298809f0b375a304cf4                        3
#
#    event_=_offer received  No of offers viewed  \
# 0                       5                    4
# 1                       5                    5
# 2                       5                    3
# 3                       4                    4
# 4                       5                    4
# 5                       5                    2
# 6                       3                    2
# 7                       5                    4
# 8                       5                    3
# 9                       4                    3
#
#    Avg reward pts for offers given  Avg offer min spend  Avg offer duration  \
# 0                         1.800000             5.000000            5.800000
# 1                         2.600000             6.400000            6.200000
# 2                         5.500000             7.500000            6.250000
# 3                         3.250000             4.250000            5.500000
# 4                         1.750000             7.500000            6.750000
# 5                         2.250000            10.000000            7.500000
# 6                         2.250000             6.250000            6.500000
# 7                         5.666667             8.333333            7.333333
# 8                         5.666667             8.333333            7.000000
# 9                         3.250000             8.000000            7.000000
#
#    No of offers given avail on mobile  No of offers given avail on social  \
# 0                                   5                                   3
# 1                                   4                                   2
# 2                                   4                                   4
# 3                                   4                                   3
# 4                                   3                                   2
# 5                                   3                                   2
# 6                                   4                                   2
# 7                                   3                                   3
# 8                                   3                                   1
# 9                                   3                                   1
#
#    No of offers given avail on web  No of offers given avail on email  \
# 0                                4                                  5
# 1                                4                                  5
# 2                                2                                  4
# 3                                3                                  4
# 4                                3                                  4
# 5                                3                                  4
# 6                                4                                  4
# 7                                2                                  3
# 8                                2                                  3
# 9                                4                                  4
#
#    No. of offers given_=_bogo  No. of offers given_=_discount  \
# 0                           1                               2
# 1                           1                               2
# 2                           2                               1
# 3                           2                               1
# 4                           0                               2
# 5                           0                               3
# 6                           1                               2
# 7                           2                               1
# 8                           2                               1
# 9                           1                               2
#
#    No. of offers given_=_informational  Total spend  No of transactions  \
# 0                                    2       127.60                   8
# 1                                    2        79.46                   5
# 2                                    1       196.86                   8
# 3                                    1       154.05                  12
# 4                                    2        48.34                  18
# 5                                    1        68.51                  17
# 6                                    1       138.36                   6
# 7                                    0       347.38                  12
# 8                                    0        20.36                   4
# 9                                    1       144.14                   5
#
#    usage_rate gender  age  became_member_on   income usage_class
# 0   60.000000      M   33          20170421  72000.0           1
# 1   60.000000      O   40          20180109  57000.0           1
# 2   60.000000      F   59          20160304  90000.0           1
# 3   75.000000      F   24          20161111  60000.0           1
# 4   60.000000      F   26          20170621  73000.0           1
# 5   20.000000      F   19          20160809  65000.0           1
# 6   66.666667      F   55          20180508  74000.0           1
# 7  100.000000      M   54          20160331  99000.0           2
# 8   20.000000      M   56          20171209  47000.0           1
# 9   75.000000      M   54          20160821  91000.0           1

# %%
df['usage_class'].unique()
# Out:
# array(['1', '2', '0'], dtype=object)

# %%
df['usage_class'].value_counts()
# Out:
# 1    10077
# 0     2834
# 2     1909
# Name: usage_class, dtype: int64

# %%
### Distribution of target classes
df['usage_class'].value_counts().plot(kind = 'bar')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '1'), Text(1, 0, '0'), Text(2, 0, '2')])

# %% [markdown]
# ### Drop columns:
# #### Person, offer_id - dropping id columns
# #### event_=_offer completed,event_=_offer received,usage_rate - dropped as they were used in creating target variable
# #### became_member_on - dropped as join_month is used instead

# %%
df = df.drop(['person','event_=_offer completed','event_=_offer received','usage_rate','became_member_on'],axis = 1)

# %%
df.head(10)
# Out:
#    No of offers viewed  Avg reward pts for offers given  Avg offer min spend  \
# 0                    4                         1.800000             5.000000
# 1                    5                         2.600000             6.400000
# 2                    3                         5.500000             7.500000
# 3                    4                         3.250000             4.250000
# 4                    4                         1.750000             7.500000
# 5                    2                         2.250000            10.000000
# 6                    2                         2.250000             6.250000
# 7                    4                         5.666667             8.333333
# 8                    3                         5.666667             8.333333
# 9                    3                         3.250000             8.000000
#
#    Avg offer duration  No of offers given avail on mobile  \
# 0            5.800000                                   5
# 1            6.200000                                   4
# 2            6.250000                                   4
# 3            5.500000                                   4
# 4            6.750000                                   3
# 5            7.500000                                   3
# 6            6.500000                                   4
# 7            7.333333                                   3
# 8            7.000000                                   3
# 9            7.000000                                   3
#
#    No of offers given avail on social  No of offers given avail on web  \
# 0                                   3                                4
# 1                                   2                                4
# 2                                   4                                2
# 3                                   3                                3
# 4                                   2                                3
# 5                                   2                                3
# 6                                   2                                4
# 7                                   3                                2
# 8                                   1                                2
# 9                                   1                                4
#
#    No of offers given avail on email  No. of offers given_=_bogo  \
# 0                                  5                           1
# 1                                  5                           1
# 2                                  4                           2
# 3                                  4                           2
# 4                                  4                           0
# 5                                  4                           0
# 6                                  4                           1
# 7                                  3                           2
# 8                                  3                           2
# 9                                  4                           1
#
#    No. of offers given_=_discount  No. of offers given_=_informational  \
# 0                               2                                    2
# 1                               2                                    2
# 2                               1                                    1
# 3                               1                                    1
# 4                               2                                    2
# 5                               3                                    1
# 6                               2                                    1
# 7                               1                                    0
# 8                               1                                    0
# 9                               2                                    1
#
#    Total spend  No of transactions gender  age   income usage_class
# 0       127.60                   8      M   33  72000.0           1
# 1        79.46                   5      O   40  57000.0           1
# 2       196.86                   8      F   59  90000.0           1
# 3       154.05                  12      F   24  60000.0           1
# 4        48.34                  18      F   26  73000.0           1
# 5        68.51                  17      F   19  65000.0           1
# 6       138.36                   6      F   55  74000.0           1
# 7       347.38                  12      M   54  99000.0           2
# 8        20.36                   4      M   56  47000.0           1
# 9       144.14                   5      M   54  91000.0           1

# %%
# To do
# Categorical encoding
# Train test split
# Feature scaling
# Hyperparameter tuning
# Model fit and evaluation metrics

# %% [markdown]
# ### Categorical features encoding for the left out categorical features - offer_type and gender

# %%
## For gender
df = pd.concat([df, pd.get_dummies(df['gender'], prefix = 'gender', prefix_sep = '_=_')], axis = 1).drop('gender', axis = 1)

# %%
df.head()
# Out:
#    No of offers viewed  Avg reward pts for offers given  Avg offer min spend  \
# 0                    4                             1.80                 5.00
# 1                    5                             2.60                 6.40
# 2                    3                             5.50                 7.50
# 3                    4                             3.25                 4.25
# 4                    4                             1.75                 7.50
#
#    Avg offer duration  No of offers given avail on mobile  \
# 0                5.80                                   5
# 1                6.20                                   4
# 2                6.25                                   4
# 3                5.50                                   4
# 4                6.75                                   3
#
#    No of offers given avail on social  No of offers given avail on web  \
# 0                                   3                                4
# 1                                   2                                4
# 2                                   4                                2
# 3                                   3                                3
# 4                                   2                                3
#
#    No of offers given avail on email  No. of offers given_=_bogo  \
# 0                                  5                           1
# 1                                  5                           1
# 2                                  4                           2
# 3                                  4                           2
# 4                                  4                           0
#
#    No. of offers given_=_discount  No. of offers given_=_informational  \
# 0                               2                                    2
# 1                               2                                    2
# 2                               1                                    1
# 3                               1                                    1
# 4                               2                                    2
#
#    Total spend  No of transactions  age   income usage_class  gender_=_F  \
# 0       127.60                   8   33  72000.0           1           0
# 1        79.46                   5   40  57000.0           1           0
# 2       196.86                   8   59  90000.0           1           1
# 3       154.05                  12   24  60000.0           1           1
# 4        48.34                  18   26  73000.0           1           1
#
#    gender_=_M  gender_=_O
# 0           1           0
# 1           0           1
# 2           0           0
# 3           0           0
# 4           0           0

# %%
df.shape
# Out:
# (14820, 19)

# %%
df.describe()
# Out:
#        No of offers viewed  Avg reward pts for offers given  \
# count         14820.000000                     14820.000000
# mean              3.364372                         4.208978
# std               1.290055                         1.524678
# min               0.000000                         0.000000
# 25%               2.000000                         3.000000
# 50%               3.000000                         4.250000
# 75%               4.000000                         5.000000
# max               6.000000                        10.000000
#
#        Avg offer min spend  Avg offer duration  \
# count         14820.000000        14820.000000
# mean              7.729500            6.512051
# std               2.502602            0.989635
# min               0.000000            3.000000
# 25%               6.000000            5.800000
# 50%               7.500000            6.500000
# 75%               9.250000            7.200000
# max              20.000000           10.000000
#
#        No of offers given avail on mobile  No of offers given avail on social  \
# count                        14820.000000                        14820.000000
# mean                             3.441768                            2.295749
# std                              0.995799                            0.968243
# min                              0.000000                            0.000000
# 25%                              3.000000                            2.000000
# 50%                              3.000000                            2.000000
# 75%                              4.000000                            3.000000
# max                              6.000000                            6.000000
#
#        No of offers given avail on web  No of offers given avail on email  \
# count                     14820.000000                       14820.000000
# mean                          3.062416                           3.829015
# std                           0.998726                           0.964542
# min                           0.000000                           1.000000
# 25%                           2.000000                           3.000000
# 50%                           3.000000                           4.000000
# 75%                           4.000000                           4.000000
# max                           6.000000                           6.000000
#
#        No. of offers given_=_bogo  No. of offers given_=_discount  \
# count                14820.000000                    14820.000000
# mean                     1.528880                        1.536302
# std                      0.864247                        0.872052
# min                      0.000000                        0.000000
# 25%                      1.000000                        1.000000
# 50%                      2.000000                        2.000000
# 75%                      2.000000                        2.000000
# max                      4.000000                        4.000000
#
#        No. of offers given_=_informational   Total spend  No of transactions  \
# count                         14820.000000  14820.000000        14820.000000
# mean                              0.763833    117.050752            8.362888
# std                               0.663785    129.980014            5.182846
# min                               0.000000      0.000000            0.000000
# 25%                               0.000000     31.457500            4.000000
# 50%                               1.000000     87.075000            7.000000
# 75%                               1.000000    160.972500           11.000000
# max                               2.000000   1608.690000           36.000000
#
#                 age         income    gender_=_F    gender_=_M    gender_=_O
# count  14820.000000   14820.000000  14820.000000  14820.000000  14820.000000
# mean      54.389069   65406.882591      0.413293      0.572402      0.014305
# std       17.383172   21598.059614      0.492441      0.494747      0.118749
# min       18.000000   30000.000000      0.000000      0.000000      0.000000
# 25%       42.000000   49000.000000      0.000000      0.000000      0.000000
# 50%       55.000000   64000.000000      0.000000      1.000000      0.000000
# 75%       66.000000   80000.000000      1.000000      1.000000      0.000000
# max      101.000000  120000.000000      1.000000      1.000000      1.000000

# %% [markdown]
# ### Train test split

# %%
x = df.drop('usage_class',axis=1)
y = df['usage_class'].astype('int')

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size = 0.2, random_state = 1234)

# %% [markdown]
# ### Feature Scaling

# %%
scaler = MinMaxScaler()

# %%
x.columns
# Out:
# Index(['No of offers viewed', 'Avg reward pts for offers given',
#        'Avg offer min spend', 'Avg offer duration',
#        'No of offers given avail on mobile',
#        'No of offers given avail on social', 'No of offers given avail on web',
#        'No of offers given avail on email', 'No. of offers given_=_bogo',
#        'No. of offers given_=_discount', 'No. of offers given_=_informational',
#        'Total spend', 'No of transactions', 'age', 'income', 'gender_=_F',
#        'gender_=_M', 'gender_=_O'],
#       dtype='object')

# %%
scaling_features = ['No of offers viewed', 'Avg reward pts for offers given', 'No of offers given avail on mobile',
       'No of offers given avail on social', 'No of offers given avail on web',
       'No of offers given avail on email', 'No. of offers given_=_bogo',
       'No. of offers given_=_discount', 'No. of offers given_=_informational',
       'Total spend', 'No of transactions', 'age', 'income']

# %%
x_train[scaling_features] = scaler.fit_transform(x_train[scaling_features])
# Out:
# C:\Users\PKN\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\PKN\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
x_test[scaling_features] = scaler.fit_transform(x_test[scaling_features])
# Out:
# C:\Users\PKN\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\PKN\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
x_train.shape,x_test.shape
# Out:
# ((11856, 18), (2964, 18))

# %%
x_train.head()
# Out:
#        No of offers viewed  Avg reward pts for offers given  \
# 7792              0.666667                         0.460000
# 5738              0.500000                         0.500000
# 6198              0.500000                         0.250000
# 5317              0.500000                         0.500000
# 11997             0.166667                         0.333333
#
#        Avg offer min spend  Avg offer duration  \
# 7792              5.400000                5.20
# 5738              5.000000                5.00
# 6198              5.500000                5.75
# 5317              5.000000                5.00
# 11997            12.333333                9.00
#
#        No of offers given avail on mobile  No of offers given avail on social  \
# 7792                             0.833333                            0.666667
# 5738                             0.333333                            0.333333
# 6198                             0.666667                            0.333333
# 5317                             0.333333                            0.333333
# 11997                            0.333333                            0.333333
#
#        No of offers given avail on web  No of offers given avail on email  \
# 7792                          0.500000                                0.8
# 5738                          0.000000                                0.2
# 6198                          0.666667                                0.6
# 5317                          0.000000                                0.2
# 11997                         0.500000                                0.4
#
#        No. of offers given_=_bogo  No. of offers given_=_discount  \
# 7792                         0.50                            0.25
# 5738                         0.25                            0.00
# 6198                         0.25                            0.50
# 5317                         0.25                            0.00
# 11997                        0.00                            0.75
#
#        No. of offers given_=_informational  Total spend  No of transactions  \
# 7792                                   1.0     0.033338            0.555556
# 5738                                   0.5     0.009784            0.111111
# 6198                                   0.5     0.149451            0.250000
# 5317                                   0.5     0.014546            0.138889
# 11997                                  0.0     0.003083            0.083333
#
#             age    income  gender_=_F  gender_=_M  gender_=_O
# 7792   0.614458  0.188889           0           1           0
# 5738   0.024096  0.044444           0           1           0
# 6198   0.493976  0.777778           1           0           0
# 5317   0.168675  0.322222           0           1           0
# 11997  0.313253  0.177778           0           1           0

# %%
x_train = np.array(x_train)
x_test= np.array(x_test)
y_train= np.array(y_train)
y_test= np.array(y_test)

# %% [markdown]
# ### Hyperparameter tuning

# %%
def hyper_model(optimizer, L1, L2):
    model = models.Sequential([layers.Input(shape = (18,)),
                               layers.Dense(32, activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = L1, l2 = L2)),
                               layers.Dropout(0.2),
                               layers.Dense(64,activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = L1, l2 = L2)),
                               layers.Dropout(0.3),
                               layers.Dense(128, activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = L1, l2 = L2)),
                               layers.Dropout(0.3),
                               layers.Dense(256,activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = L1, l2 = L2)),
                               layers.Dropout(0.4),
                               layers.Dense(512,activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = L1, l2 = L2)),
                               layers.Dropout(0.4),
                               layers.Dense(32,activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = L1, l2 = L2)),
                               layers.Dropout(0.2),
                               layers.Dense(3,activation = 'softmax')])
    model.compile(optimizer = optimizer, loss ='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

random_model = KerasClassifier(build_fn = hyper_model)
parameters = {'batch_size': [32,64,128],'epochs' : [5,10], 'optimizer' : ['adam','SGD','Adadelta'],
             'L1': [1e-3,1e-4,1e-5],'L2': [1e-3,1e-4,1e-5]}

#clf = model_selection.GridSearchCV(tree.DecisionTreeClassifier(), parameters, cv = model_selection.StratifiedKFold(n_splits = 10, shuffle = True, random_state = 1234))
clf = model_selection.RandomizedSearchCV(random_model,param_distributions = parameters, cv = model_selection.StratifiedKFold(n_splits = 5, shuffle = True, random_state = 1234), n_iter = 20, scoring = 'accuracy')
clf.fit(x_train, y_train)
print('best parameters: ', clf.best_params_)
# Out:
# Epoch 1/10
# 149/149 [==============================] - 1s 8ms/step - loss: 12.3866 - accuracy: 0.1369
# Epoch 2/10
# 149/149 [==============================] - 1s 9ms/step - loss: 12.2185 - accuracy: 0.1428
# Epoch 3/10
# 149/149 [==============================] - 1s 9ms/step - loss: 12.0728 - accuracy: 0.1575
# Epoch 4/10
# 149/149 [==============================] - 1s 9ms/step - loss: 11.9539 - accuracy: 0.1786
# Epoch 5/10
# 149/149 [==============================] - 1s 8ms/step - loss: 11.8607 - accuracy: 0.1998
# Epoch 6/10
# 149/149 [==============================] - 1s 8ms/step - loss: 11
5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.2891 - accuracy: 0.3071
# Epoch 2/5
# 149/149 [==============================] - 1s 9ms/step - loss: 1.2424 - accuracy: 0.3631: 0s - loss:
# Epoch 3/5
# 149/149 [==============================] - 1s 8ms/step - loss: 1.2151 - accuracy: 0.4076
# Epoch 4/5
# 149/149 [==============================] - 1s 9ms/step - loss: 1.1836 - accuracy: 0.4440
# Epoch 5/5
# 149/149 [==============================] - 1s 8ms/step - loss: 1.1660 - accuracy: 0.4812
# Epoch 1/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.2385 - accuracy: 0.3947
# Epoch 2/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.1940 - accuracy: 0.4334
# Epoch 3/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.1610 - accuracy: 0.4811
# Epoch 4/5
# 149/149 [==============================] - 1s 6ms/step - loss: 1.1330 - accuracy: 0.5161
# Epoch 5/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.1131 - accuracy: 0.5387
# Epoch 1/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.1322 - accuracy: 0.5109
# Epoch 2/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.1138 - accuracy: 0.5506
# Epoch 3/5
# 149/149 [==============================] - 1s 8ms/step - loss: 1.1060 - accuracy: 0.5700
# Epoch 4/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.0881 - accuracy: 0.5975
# Epoch 5/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.0764 - accuracy: 0.6065
# Epoch 1/5
# 149/149 [==============================] - 1s 8ms/step - loss: 5.3505 - accuracy: 0.6739
# Epoch 2/5
# 149/149 [==============================] - 1s 9ms/step - loss: 1.4149 - accuracy: 0.6807
# Epoch 3/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.0423 - accuracy: 0.6807
# Epoch 4/5
# 149/149 [==============================] - 1s 9ms/step - loss: 0.9577 - accuracy: 0.6807
# Epoch 5/5
# 149/149 [==============================] - 1s 8ms/step - loss: 0.9223 - accuracy: 0.6807
# Epoch 1/5
# 149/149 [==============================] - 1s 8ms/step - loss: 5.7363 - accuracy: 0.6771
# Epoch 2/5
# 149/149 [==============================] - 1s 9ms/step - loss: 1.5381 - accuracy: 0.6807
# Epoch 3/5
# 149/149 [==============================] - 1s 8ms/step - loss: 1.0245 - accuracy: 0.6807
# Epoch 4/5
# 149/149 [==============================] - 1s 9ms/step - loss: 0.9226 - accuracy: 0.6807
# Epoch 5/5
# 149/149 [==============================] - 1s 7ms/step - loss: 0.8913 - accuracy: 0.6807
# Epoch 1/5
# 149/149 [==============================] - 1s 7ms/step - loss: 5.3723 - accuracy: 0.6789
# Epoch 2/5
# 149/149 [==============================] - 1s 6ms/step - loss: 1.3981 - accuracy: 0.6807
# Epoch 3/5
# 149/149 [==============================] - 1s 6ms/step - loss: 1.0038 - accuracy: 0.6807
# Epoch 4/5
# 149/149 [==============================] - 1s 6ms/step - loss: 0.9154 - accuracy: 0.6807
# Epoch 5/5
# 149/149 [==============================] - 1s 6ms/step - loss: 0.8890 - accuracy: 0.6807
# Epoch 1/5
# 149/149 [==============================] - 1s 6ms/step - loss: 5.7933 - accuracy: 0.6782
# Epoch 2/5
# 149/149 [==============================] - 1s 6ms/step - loss: 1.5903 - accuracy: 0.6807
# Epoch 3/5
# 149/149 [==============================] - 1s 9ms/step - loss: 1.0500 - accuracy: 0.6807: 0s - loss: 1.091
# Epoch 4/5
# 149/149 [==============================] - 1s 6ms/step - loss: 0.9305 - accuracy: 0.6807
# Epoch 5/5
# 149/149 [==============================] - 1s 6ms/step - loss: 0.8957 - accuracy: 0.6807
# Epoch 1/5
# 149/149 [==============================] - 1s 8ms/step - loss: 5.7008 - accuracy: 0.6763
# Epoch 2/5
# 149/149 [==============================] - 1s 9ms/step - loss: 1.5452 - accuracy: 0.6807
# Epoch 3/5
# 149/149 [==============================] - 1s 8ms/step - loss: 1.0367 - accuracy: 0.6807
# Epoch 4/5
# 149/149 [==============================] - 1s 9ms/step - loss: 0.9271 - accuracy: 0.6807
# Epoch 5/5
# 149/149 [==============================] - 1s 8ms/step - loss: 0.8913 - accuracy: 0.6807
# Epoch 1/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.7028 - accuracy: 0.6795
# Epoch 2/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.3878 - accuracy: 0.6807
# Epoch 3/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.1654 - accuracy: 0.6802: 0s - loss: 1.229
# Epoch 4/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.9786 - accuracy: 0.6860
# Epoch 5/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.8628 - accuracy: 0.6901
# Epoch 6/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.7808 - accuracy: 0.7043
# Epoch 7/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.7311 - accuracy: 0.7264
# Epoch 8/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.7035 - accuracy: 0.7286
# Epoch 9/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.6762 - accuracy: 0.7391: 0s - loss: 0.6
# Epoch 10/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.6593 - accuracy: 0.7400
# Epoch 1/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.6744 - accuracy: 0.6785
# Epoch 2/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.3532 - accuracy: 0.6807
# Epoch 3/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.1524 - accuracy: 0.6807: 0s - loss: 1.1722 - accuracy:
# Epoch 4/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.0102 - accuracy: 0.6800
# Epoch 5/10
# 149/149 [==============================] - 1s 9ms/step - loss: 0.9132 - accuracy: 0.6837
# Epoch 6/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.8408 - accuracy: 0.6862
# Epoch 7/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0.7765 - accuracy: 0.6929
# Epoch 8/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0.7509 - accuracy: 0.6895
# Epoch 9/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0.7079 - accuracy: 0.7062
# Epoch 10/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0.6818 - accuracy: 0.7127
# Epoch 1/10
# 149/149 [==============================] - 1s 8ms/step - loss: 1.6971 - accuracy: 0.6760
# Epoch 2/10
# 149/149 [==============================] - 1s 8ms/step - loss: 1.3792 - accuracy: 0.6805
# Epoch 3/10
# 149/149 [==============================] - 1s 8ms/step - loss: 1.1594 - accuracy: 0.6812
# Epoch 4/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.0008 - accuracy: 0.6812
# Epoch 5/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0.8736 - accuracy: 0.6869
# Epoch 6/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0.8069 - accuracy: 0.6902
# Epoch 7/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0.7417 - accuracy: 0.7110
# Epoch 8/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0.7134 - accuracy: 0.7132
# Epoch 9/10
# 149/149 [==============================] - 1s 7ms/step - loss: 0.6892 - accuracy: 0.7244
# Epoch 10/10
# 149/149 [==============================] - 1s 6ms/step - loss: 0.6758 - accuracy: 0.7234
# Epoch 1/10
# 149/149 [==============================] - 1s 9ms/step - loss: 1.6716 - accuracy: 0.6772
# Epoch 2/10
# 149/149 [==============================] - 1s 8ms/step - loss: 1.3351 - accuracy: 0.6808
# Epoch 3/10
# 149/149 [==============================] - 1s 8ms/step - loss: 1.0973 - accuracy: 0.6829
# Epoch 4/10
# 149/149 [==============================] - 1s 8ms/step - loss: 0
5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.3492 - accuracy: 0.2701
# Epoch 2/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.3160 - accuracy: 0.3152
# Epoch 3/5
# 149/149 [==============================] - 1s 7ms/step - loss: 1.2869 - accuracy: 0.3441
# Epoch 4/5
# 149/149 [==============================] - 1s 8ms/step - loss: 1.2541 - accuracy: 0.3927
# Epoch 5/5
# 149/149 [==============================] - 1s 8ms/step - loss: 1.2355 - accuracy: 0.4331
# Epoch 1/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.7083 - accuracy: 0.6359
# Epoch 2/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.5172 - accuracy: 0.6758
# Epoch 3/10
# 75/75 [==============================] - 1s 8ms/step - loss: 10.3580 - accuracy: 0.6803
# Epoch 4/10
# 75/75 [==============================] - 1s 8ms/step - loss: 10.2043 - accuracy: 0.6807
# Epoch 5/10
# 75/75 [==============================] - 1s 8ms/step - loss: 10.0529 - accuracy: 0.6806 0s - loss: 10.0854 - accura
# Epoch 6/10
# 75/75 [==============================] - 1s 8ms/step - loss: 9.9054 - accuracy: 0.6807
# Epoch 7/10
# 75/75 [==============================] - 1s 8ms/step - loss: 9.7626 - accuracy: 0.6807
# Epoch 8/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.6195 - accuracy: 0.6807
# Epoch 9/10
# 75/75 [==============================] - 1s 8ms/step - loss: 9.4783 - accuracy: 0.6807
# Epoch 10/10
# 75/75 [==============================] - 1s 8ms/step - loss: 9.3400 - accuracy: 0.6807
# Epoch 1/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.7422 - accuracy: 0.6178
# Epoch 2/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.5360 - accuracy: 0.6768
# Epoch 3/10
# 75/75 [==============================] - 1s 8ms/step - loss: 10.3691 - accuracy: 0.6792
# Epoch 4/10
# 75/75 [==============================] - 1s 10ms/step - loss: 10.2179 - accuracy: 0.6807
# Epoch 5/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.0689 - accuracy: 0.6804
# Epoch 6/10
# 75/75 [==============================] - 1s 10ms/step - loss: 9.9177 - accuracy: 0.6807
# Epoch 7/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.7766 - accuracy: 0.6807
# Epoch 8/10
# 75/75 [==============================] - 1s 8ms/step - loss: 9.6348 - accuracy: 0.6807
# Epoch 9/10
# 75/75 [==============================] - 1s 12ms/step - loss: 9.4919 - accuracy: 0.6807
# Epoch 10/10
# 75/75 [==============================] - 1s 11ms/step - loss: 9.3564 - accuracy: 0.6807
# Epoch 1/10
# 75/75 [==============================] - 1s 10ms/step - loss: 10.7540 - accuracy: 0.6093
# Epoch 2/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.5353 - accuracy: 0.6770
# Epoch 3/10
# 75/75 [==============================] - 1s 8ms/step - loss: 10.3750 - accuracy: 0.6795
# Epoch 4/10
# 75/75 [==============================] - 1s 8ms/step - loss: 10.2228 - accuracy: 0.6805
# Epoch 5/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.0685 - accuracy: 0.6805
# Epoch 6/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.9232 - accuracy: 0.6807
# Epoch 7/10
# 75/75 [==============================] - 1s 10ms/step - loss: 9.7793 - accuracy: 0.6807
# Epoch 8/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.6352 - accuracy: 0.6807
# Epoch 9/10
# 75/75 [==============================] - 1s 10ms/step - loss: 9.4963 - accuracy: 0.6807
# Epoch 10/10
# 75/75 [==============================] - 1s 10ms/step - loss: 9.3594 - accuracy: 0.6807
# Epoch 1/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.7211 - accuracy: 0.6271
# Epoch 2/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.5195 - accuracy: 0.6778
# Epoch 3/10
# 75/75 [==============================] - 1s 8ms/step - loss: 10.3631 - accuracy: 0.6808
# Epoch 4/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.2156 - accuracy: 0.6809
# Epoch 5/10
# 75/75 [==============================] - 1s 9ms/step - loss: 10.0616 - accuracy: 0.6807
# Epoch 6/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.9150 - accuracy: 0.6807
# Epoch 7/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.7695 - accuracy: 0.6807
# Epoch 8/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.6230 - accuracy: 0.6807
# Epoch 9/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.4850 - accuracy: 0.6807
# Epoch 10/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.3469 - accuracy: 0.6807
# Epoch 1/10
# 75/75 [==============================] - 1s 10ms/step - loss: 10.7453 - accuracy: 0.6094
# Epoch 2/10
# 75/75 [==============================] - 1s 11ms/step - loss: 10.5285 - accuracy: 0.6752
# Epoch 3/10
# 75/75 [==============================] - 1s 10ms/step - loss: 10.3706 - accuracy: 0.6782
# Epoch 4/10
# 75/75 [==============================] - 1s 10ms/step - loss: 10.2174 - accuracy: 0.6800
# Epoch 5/10
# 75/75 [==============================] - 1s 8ms/step - loss: 10.0689 - accuracy: 0.6807
# Epoch 6/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.9224 - accuracy: 0.6807
# Epoch 7/10
# 75/75 [==============================] - 1s 11ms/step - loss: 9.7771 - accuracy: 0.6807
# Epoch 8/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.6350 - accuracy: 0.6807
# Epoch 9/10
# 75/75 [==============================] - 1s 10ms/step - loss: 9.4963 - accuracy: 0.6807
# Epoch 10/10
# 75/75 [==============================] - 1s 9ms/step - loss: 9.3528 - accuracy: 0.6807
# Epoch 1/5
# 149/149 [==============================] - 1s 6ms/step - loss: 10.5567 - accuracy: 0.6603
# Epoch 2/5
# 149/149 [==============================] - 1s 6ms/step - loss: 10.2327 - accuracy: 0.6798
# Epoch 3/5
# 149/149 [==============================] - 1s 6ms/step - loss: 9.9389 - accuracy: 0.6806
# Epoch 4/5
5
# 297/297 [==============================] - 1s 5ms/step - loss: 1.8825 - accuracy: 0.6807
# Epoch 4/5
# 297/297 [==============================] - 1s 5ms/step - loss: 1.8687 - accuracy: 0.6807
# Epoch 5/5
# 297/297 [==============================] - 1s 5ms/step - loss: 1.8539 - accuracy: 0.6807
# Epoch 1/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.7650 - accuracy: 0.6680
# Epoch 2/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.4907 - accuracy: 0.6807
# Epoch 3/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.3010 - accuracy: 0.6807
# Epoch 4/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.1665 - accuracy: 0.6807
# Epoch 5/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.0655 - accuracy: 0.6806
# Epoch 6/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.9887 - accuracy: 0.6807
# Epoch 7/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.9176 - accuracy: 0.6803
# Epoch 8/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.8547 - accuracy: 0.6805
# Epoch 9/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.8045 - accuracy: 0.6843
# Epoch 10/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.7685 - accuracy: 0.6848
# Epoch 1/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.7778 - accuracy: 0.6691
# Epoch 2/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.5183 - accuracy: 0.6808
# Epoch 3/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.3341 - accuracy: 0.6807
# Epoch 4/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.1942 - accuracy: 0.6794
# Epoch 5/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.0884 - accuracy: 0.6792
# Epoch 6/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.9918 - accuracy: 0.6811
# Epoch 7/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.9171 - accuracy: 0.6839
# Epoch 8/10
# 75/75 [==============================] - 1s 11ms/step - loss: 0.8503 - accuracy: 0.6874
# Epoch 9/10
# 75/75 [==============================] - 1s 11ms/step - loss: 0.8047 - accuracy: 0.6931
# Epoch 10/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.7669 - accuracy: 0.6969
# Epoch 1/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.7884 - accuracy: 0.6742
# Epoch 2/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.5541 - accuracy: 0.6807
# Epoch 3/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.3853 - accuracy: 0.6807
# Epoch 4/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.2497 - accuracy: 0.6807
# Epoch 5/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.1440 - accuracy: 0.6807
# Epoch 6/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.0497 - accuracy: 0.6805
# Epoch 7/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.9671 - accuracy: 0.6797
# Epoch 8/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.9016 - accuracy: 0.6836
# Epoch 9/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.8438 - accuracy: 0.6857
# Epoch 10/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.7888 - accuracy: 0.7002
# Epoch 1/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.7720 - accuracy: 0.6731
# Epoch 2/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.5160 - accuracy: 0.6807
# Epoch 3/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.3316 - accuracy: 0.6807
# Epoch 4/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.1872 - accuracy: 0.6807
# Epoch 5/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.0695 - accuracy: 0.6797
# Epoch 6/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.9700 - accuracy: 0.6792
# Epoch 7/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.8888 - accuracy: 0.6872
# Epoch 8/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.8280 - accuracy: 0.6927
# Epoch 9/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.7822 - accuracy: 0.7012
# Epoch 10/10
# 75/75 [==============================] - 1s 10ms/step - loss: 0.7534 - accuracy: 0.7070
# Epoch 1/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.7941 - accuracy: 0.6719
# Epoch 2/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.5368 - accuracy: 0.6807
# Epoch 3/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.3521 - accuracy: 0.6807
# Epoch 4/10
# 75/75 [==============================] - 1s 10ms/step - loss: 1.2127 - accuracy: 0.6807
# Epoch 5/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.0953 - accuracy: 0.6800
# Epoch 6/10
# 75/75 [==============================] - 1s 9ms/step - loss: 1.0010 - accuracy: 0.6793
# Epoch 7/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.9353 - accuracy: 0.6841
# Epoch 8/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.8603 - accuracy: 0.6861
# Epoch 9/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.8158 - accuracy: 0.6875
# Epoch 10/10
# 75/75 [==============================] - 1s 9ms/step - loss: 0.7602 - accuracy: 0.6972
# Epoch 1/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.9024 - accuracy: 0.6716
# Epoch 2/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8570 - accuracy: 0.6807
# Epoch 3/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8419 - accuracy: 0.6807
# Epoch 4/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8270 - accuracy: 0.6807
# Epoch 5/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8145 - accuracy: 0.6807
# Epoch 6/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8111 - accuracy: 0.6807
# Epoch 7/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8016 - accuracy: 0.6807
# Epoch 8/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.7984 - accuracy: 0.6807
# Epoch 9/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.7925 - accuracy: 0.6807
# Epoch 10/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.7858 - accuracy: 0.6807
# Epoch 1/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.9050 - accuracy: 0.6493
# Epoch 2/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8652 - accuracy: 0.6802
# Epoch 3/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8455 - accuracy: 0.6805
# Epoch 4/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8368 - accuracy: 0.6807
# Epoch 5/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8293 - accuracy: 0.6807
# Epoch 6/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8211 - accuracy: 0.6807
# Epoch 7/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8129 - accuracy: 0.6807
# Epoch 8/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8062 - accuracy: 0.6807
# Epoch 9/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8032 - accuracy: 0.6807
# Epoch 10/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.7984 - accuracy: 0.6807
# Epoch 1/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.9050 - accuracy: 0.6628
# Epoch 2/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8676 - accuracy: 0.6801
# Epoch 3/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8486 - accuracy: 0.6807
# Epoch 4/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8374 - accuracy: 0.6807
# Epoch 5/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8258 - accuracy: 0.6807
# Epoch 6/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8187 - accuracy: 0.6807
# Epoch 7/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8099 - accuracy: 0.6807
# Epoch 8/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8057 - accuracy: 0.6807
# Epoch 9/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.7990 - accuracy: 0.6807
# Epoch 10/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.7947 - accuracy: 0.6807
# Epoch 1/10
# 149/149 [==============================] - 1s 8ms/step - loss: 1.9224 - accuracy: 0.6490
# Epoch 2/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8738 - accuracy: 0.6803
# Epoch 3/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8547 - accuracy: 0.6808
# Epoch 4/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.8430 - accuracy: 0.6805
# Epoch 5/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8282 - accuracy: 0.6807
# Epoch 6/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8206 - accuracy: 0.6807
# Epoch 7/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8110 - accuracy: 0.6807
# Epoch 8/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8036 - accuracy: 0.6807
# Epoch 9/10
# 149/149 [==============================] - 1s 7ms/step - loss: 1.7986 - accuracy: 0.6807
# Epoch 10/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.7943 - accuracy: 0.6807
# Epoch 1/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.9333 - accuracy: 0.6433
# Epoch 2/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8691 - accuracy: 0.6798
# Epoch 3/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8544 - accuracy: 0.6808
# Epoch 4/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8363 - accuracy: 0.6807
# Epoch 5/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8296 - accuracy: 0.6807
# Epoch 6/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8222 - accuracy: 0.6807: 0s -
# Epoch 7/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8142 - accuracy: 0.6807
# Epoch 8/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8067 - accuracy: 0.6807
# Epoch 9/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.8012 - accuracy: 0.6807
# Epoch 10/10
# 149/149 [==============================] - 1s 6ms/step - loss: 1.7954 - accuracy: 0.6807
# Epoch 1/10
# 186/186 [==============================] - 1s 6ms/step - loss: 1.6670 - accuracy: 0.6761
# Epoch 2/10
# 186/186 [==============================] - 1s 6ms/step - loss: 1.3070 - accuracy: 0.6806
# Epoch 3/10
# 186/186 [==============================] - 1s 7ms/step - loss: 1.0629 - accuracy: 0.6813
# Epoch 4/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.8853 - accuracy: 0.6872
# Epoch 5/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.7758 - accuracy: 0.7091
# Epoch 6/10
# 186/186 [==============================] - 1s 6ms/step - loss: 0.7240 - accuracy: 0.7114
# Epoch 7/10
# 186/186 [==============================] - 1s 6ms/step - loss: 0.6903 - accuracy: 0.7260
# Epoch 8/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.6670 - accuracy: 0.7352
# Epoch 9/10
# 186/186 [==============================] - 1s 6ms/step - loss: 0.6498 - accuracy: 0.7406
# Epoch 10/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.6297 - accuracy: 0.7483
# best parameters:  {'optimizer': 'adam', 'epochs': 10, 'batch_size': 64, 'L2': 1e-05, 'L1': 0.0001}

# %% [markdown]
# ### Model fitting and obtaining evaluation metrics

# %%
model = models.Sequential()

# %%
model.add(layers.Input(shape = (18,)))
model.add(layers.Dense(32, activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = 0.0001, l2 = 1e-05)))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(64,activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = 0.0001, l2 = 1e-05)))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(128, activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = 0.0001, l2 = 1e-05)))
model.add(layers.Dropout(0.3))
model.add(layers.Dense(256,activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = 0.0001, l2 = 1e-05)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(512,activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = 0.0001, l2 = 1e-05)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(32,activation = 'relu', kernel_regularizer = regularizers.l1_l2(l1 = 0.0001, l2 = 1e-05)))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(3,activation = 'softmax'))

# %%
print(model.summary())
# Out:
# Model: "sequential_202"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1414 (Dense)           (None, 32)                608
# _________________________________________________________________
# dropout_1212 (Dropout)       (None, 32)                0
# _________________________________________________________________
# dense_1415 (Dense)           (None, 64)                2112
# _________________________________________________________________
# dropout_1213 (Dropout)       (None, 64)                0
# _________________________________________________________________
# dense_1416 (Dense)           (None, 128)               8320
# _________________________________________________________________
# dropout_1214 (Dropout)       (None, 128)               0
# _________________________________________________________________
# dense_1417 (Dense)           (None, 256)               33024
# _________________________________________________________________
# dropout_1215 (Dropout)       (None, 256)               0
# _________________________________________________________________
# dense_1418 (Dense)           (None, 512)               131584
# _________________________________________________________________
# dropout_1216 (Dropout)       (None, 512)               0
# _________________________________________________________________
# dense_1419 (Dense)           (None, 32)                16416
# _________________________________________________________________
# dropout_1217 (Dropout)       (None, 32)                0
# _________________________________________________________________
# dense_1420 (Dense)           (None, 3)                 99
# =================================================================
# Total params: 192,163
# Trainable params: 192,163
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer = 'adam', loss ='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, validation_data = (x_test, y_test),batch_size = 64, epochs = 10)
# Out:
# Epoch 1/10
# 186/186 [==============================] - 2s 9ms/step - loss: 1.5616 - accuracy: 0.6748 - val_loss: 1.2736 - val_accuracy: 0.6771
# Epoch 2/10
# 186/186 [==============================] - 1s 8ms/step - loss: 1.1456 - accuracy: 0.6806 - val_loss: 0.9669 - val_accuracy: 0.6771
# Epoch 3/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.9409 - accuracy: 0.6822 - val_loss: 0.8088 - val_accuracy: 0.6771
# Epoch 4/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.8335 - accuracy: 0.6856 - val_loss: 0.7255 - val_accuracy: 0.6771
# Epoch 5/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.7550 - accuracy: 0.6939 - val_loss: 0.6570 - val_accuracy: 0.7156
# Epoch 6/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.7137 - accuracy: 0.6948 - val_loss: 0.6129 - val_accuracy: 0.7598
# Epoch 7/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.6822 - accuracy: 0.7115 - val_loss: 0.6037 - val_accuracy: 0.7655
# Epoch 8/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.6653 - accuracy: 0.7190 - val_loss: 0.5966 - val_accuracy: 0.7672
# Epoch 9/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.6543 - accuracy: 0.7246 - val_loss: 0.5607 - val_accuracy: 0.7891
# Epoch 10/10
# 186/186 [==============================] - 1s 7ms/step - loss: 0.6376 - accuracy: 0.7355 - val_loss: 0.5686 - val_accuracy: 0.7912

# %%
def plot_history(key):
    plt.figure(figsize=(16,10))
    val = plt.plot(history.epoch, history.history['val_'+key], '--', label='validation_' + key)
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),label= 'training_' + key)
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel(key)
    plt.xlim([0,max(history.epoch)])

# %%
plot_history('accuracy')

# %%
plot_history('loss')

# %%
model_prob = model.predict(x_test)

# %%
model_prob
# Out:
# array([[6.9131996e-03, 9.9192989e-01, 1.1568964e-03],
#        [1.1150398e-02, 7.0109427e-01, 2.8775528e-01],
#        [7.9544019e-03, 9.8995882e-01, 2.0868685e-03],
#        ...,
#        [1.0695882e-03, 4.8434201e-01, 5.1458842e-01],
#        [2.2575385e-03, 9.9715626e-01, 5.8615260e-04],
#        [2.2820018e-02, 9.6831679e-01, 8.8630999e-03]], dtype=float32)

# %%
y_pred = np.argmax(model_prob, axis = -1)

# %%
dnn_report = """
The evaluation report of Deep neural network is:
Confusion Matrix:
{}
Accuracy: {}
""".format(metrics.confusion_matrix(y_test, y_pred),
           metrics.accuracy_score(y_test, y_pred))
print(dnn_report)
print('The classification report of Deep neural network:\n {}'
      .format(metrics.classification_report(y_test, y_pred)))
# Out:
# The evaluation report of Deep neural network is:
# Confusion Matrix:
# [[ 310  253    0]
#  [ 109 1837   61]
#  [   3  193  198]]
# Accuracy: 0.7911605937921727
#
# The classification report of Deep neural network:
#                precision    recall  f1-score   support
#
#            0       0.73      0.55      0.63       563
#            1       0.80      0.92      0.86      2007
#            2       0.76      0.50      0.61       394
#
#     accuracy                           0.79      2964
#    macro avg       0.77      0.66      0.70      2964
# weighted avg       0.79      0.79      0.78      2964

# %%
n_classes = 3

# %%
#y_train = label_binarize(y_train, classes=[0, 1, 2])
y_test = label_binarize(y_test, classes=[0, 1, 2])

# %%
y_test
# Out:
# array([[0, 1, 0],
#        [0, 1, 0],
#        [0, 1, 0],
#        ...,
#        [0, 0, 1],
#        [0, 1, 0],
#        [0, 1, 0]])

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:,i], model_prob[:,i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), model_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
lw = 2
# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.3f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.3f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.3f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of the multi-class')
plt.legend(loc="lower right")
plt.show()

# %%
import shap
# load JS visualization code to notebook
shap.initjs()

explainer = shap.DeepExplainer(model, x_test)
shap_values = explainer.shap_values(x_test)
shap.summary_plot(shap_values, x_test, plot_type="bar")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
cols = ['No of offers viewed', 'Avg reward pts for offers given', 'Avg offer min spend',
       'Avg offer duration', 'No of offers given avail on mobile',
       'No of offers given avail on social', 'No of offers given avail on web',
       'No of offers given avail on email', 'No. of offers given_=_bogo',
       'No. of offers given_=_discount', 'No. of offers given_=_informational',
       'Total spend', 'No of transactions', 'age', 'income',
       'gender_=_F', 'gender_=_M', 'gender_=_O']
feature_names = pd.Series(cols)

# %%
feature_names
# Out:
# 0                     No of offers viewed
# 1         Avg reward pts for offers given
# 2                     Avg offer min spend
# 3                      Avg offer duration
# 4      No of offers given avail on mobile
# 5      No of offers given avail on social
# 6         No of offers given avail on web
# 7       No of offers given avail on email
# 8              No. of offers given_=_bogo
# 9          No. of offers given_=_discount
# 10    No. of offers given_=_informational
# 11                            Total spend
# 12                     No of transactions
# 13                                    age
# 14                                 income
# 15                             gender_=_F
# 16                             gender_=_M
# 17                             gender_=_O
# dtype: object
